# %%
from sklearn.datasets import load_boston
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# %%
data = load_boston()

# %%
features = data.feature_names
X = data.data
Y = data.target

# %%
plt.figure(figsize=(8, 4))
plt.hist(Y, bins = 20)
plt.xlabel('price ($1000s)')
plt.ylabel('count')
plt.tight_layout()

# %%
for i, f in enumerate(features):
    plt.figure(figsize=(8, 4))
    plt.scatter(X[:, i], Y)
    plt.ylabel('Price', size=15)
    plt.xlabel(f, size=15)
    plt.tight_layout()

# %%
X_train, X_test, y_train, y_test = train_test_split(X, Y)
print(X_train.shape, X_test.shape)
# Out:
# ((379, 13), (127, 13))

# %%
clf = LinearRegression()
clf.fit(X_train, y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=1, normalize=False)

# %%
clf.coef_
# Out:
# array([-1.02969245e-01,  5.80388604e-02,  2.22299138e-02,  2.06225842e+00,
#        -1.90896426e+01,  3.16810858e+00,  9.35013743e-03, -1.70436561e+00,
#         3.12402585e-01, -1.34835261e-02, -1.04555018e+00,  9.97622082e-03,
#        -6.19280267e-01])

# %%
predicted = clf.predict(X_test)
expected = y_test

plt.figure(figsize=(8, 4))
plt.scatter(expected, predicted)
plt.plot([0, 50], [0, 50], '--k')
plt.axis('tight')
plt.xlabel('True price ($1000s)')
plt.ylabel('Predicted price ($1000s)')
plt.tight_layout()

# %%
print('MAE = ', mean_absolute_error(expected, predicted))
print('MSE = ', mean_squared_error(expected, predicted))
print('R2 = ', r2_score(expected, predicted))
# Out:
# ('MAE = ', 3.6532793064726254)
# ('MSE = ', 25.527433920875666)
# ('R2 = ', 0.6502251190099599)
